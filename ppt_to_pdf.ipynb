# %% [markdown]
# <a href="https://colab.research.google.com/github/Murad460/convert-mp3-to-mp4/blob/main/ppt_to_pdf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install aspose.slides
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.7/104.7 MB 4.0 MB/s eta 0:00:00
# ...

# %%
import aspose.slides as slides

# Create a Presentation instance and load the input file
with slides.Presentation("/content/AutoBreakAI-Intelligent-Malware-Classifier-and-Adaptive-Attack-Simulator.pptx") as presentation:
    # Save the presentation as a PDF file
    presentation.save("output_document.pdf", slides.export.SaveFormat.PDF)
